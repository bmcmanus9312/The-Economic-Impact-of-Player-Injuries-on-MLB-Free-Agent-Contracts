# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\brend\Desktop\SABR_research_proposal\injuries\processed\injuries_cleaned_v1_5.csv")

# %%
df['inj_norm_v4'] = (
    df['inj_norm_v3']
)

df.head(1)
# Out:
#      player_name team pos inj_start  inj_desc         status   il_retro  \
# 0  Julio Teheran  LAA  SP  7/1/2020  COVID-19  Active roster  7/20/2020
#
#   eligible_return return_date latest_update  ... mlbamid  season  \
# 0             NaN    8/5/2020     Activated  ...  527054    2020
#
#          source_file  days_to_return flag_negative_days_to_return  \
# 0  2020_injuries.csv            35.0                        False
#
#            inj_norm       inj_norm_v1       inj_norm_v2       inj_norm_v3  \
# 0  COVID-19_related  COVID-19_related  COVID-19_related  COVID-19_related
#
#         inj_norm_v4
# 0  COVID-19_related
#
# [1 rows x 22 columns]

# %%
unique_injuries = df['inj_norm_v4'].unique()

print(f"Number of unique injury descriptions: {len(unique_injuries)}")

# Number of unique injury descriptions: 337
# Out:
# Number of unique injury descriptions: 337

# %%
# list of all terms remaining
# print(df['inj_norm_v4'].unique().tolist())

# %%
# TERM SEARCH KEY
filtered_entries = df['inj_norm_v4'][df['inj_norm_v4'].str.contains('covid', case=False, na=False)]
unique_infections = filtered_entries.unique() #
unique_infections_list = unique_infections.tolist()
print(unique_infections_list)
print(f"Number of unique infection-related injuries: {len(unique_infections)}")

# %% [markdown]
# Canon Terms
# * Fractured rib
# * Fractured forearm
# * Fractured hand
# * Fractured finger
# * Fractured foot
# * Fractured toe
# * Fractured elbow
# * Fractured wrist
# * Lower back stress fracture
# * Facial Fracture
# * Fractured nose
# * Fractured ankle
# * Fractured shoulder
# * Fractured pelvis (hip canon)
# * Fractured shin (COME BACK TO THIS)
# * Fractured knee
# * Skull fracture
#
# Stress Fractures
# * Toe stress fracture
# * Leg stress fracture
#
# Facial Fractures
# * Facial fracture

# %%
# Fracture Injury Term v2 Mapping

fractures_map = {
    'Stress fracture, fourth left toe': 'Toe stress fracture',
    'Leg stress fracture (fibular head)': 'Leg stress fracture',
    'Nasal and facial fractures': 'Facial fracture',
    'Facial fractures': 'Facial fracture',
    'Fractured jaw': 'Facial fracture',
    'Rib fracture': 'Fractured rib',
    'Fractured hand (non-throwing)': 'Fractured hand',
    'Non-displaced thumb fracture (right)': 'Fractured finger',
    'Fractured hamate': 'Fractured hand',
    'Fractured hamate (left)': 'Fractured hand',
    'Fractured hand (left)': 'Fractured hand',
    'Fractured fibula': 'Fractured leg',
    'Fractured hand (right)': 'Fractured hand',
    'Fractured thumb': 'Fractured finger',
    'Hairline fracture (leg)': 'Fractured leg',
    'Fractured right hand (fifth metacarpal)': 'Fractured hand',
    'Fractured thumb (left)': 'Fractured finger',
    'Fractured finger (right)': 'Fractured finger',
    'Fractured hand (right pinkie)': 'Fractured finger',
    'Fractured thumb (right)': 'Fractured finger',
    'Fractured toe (sesmoid)': 'Fractured toe',
    'Shoulder fracture': 'Fractured shoulder',
    'Foot fracture': 'Fractured foot',
    'Fractured hand (hamate)': 'Fractured hand',
    'Fractured leg (fibula)': 'Fractured leg',
    'Fractured foot (non-displaced)': 'Fractured foot',
    'Fractured heel': 'Fractured foot',
    'Fractured finger (left pinkie)': 'Fractured finger', 
    'Fractured hamate (left hand)': 'Fractured hand',
    'Fractured ankle (non-displaced)': 'Fractured ankle',
     'Hairline fracture in hand (right)': 'Fractured hand'
}

df["inj_norm_v4"] = (
    df["inj_norm_v4"]
        .astype("string")
        .str.strip()
        .replace(fractures_map)
)

'''
# DO THESE AT THE END
['Shoulder discomfort (scapular stress fracture)', 'Strained lower back/ Rib stress fracture',
 'Concussion/fractured jaw', 'Sports hernia stress fracture',
 'Fractured foot (third metatarsal) / lisfranc sprai'
]
'''

# 312 unique
# Out:
# "\n# DO THESE AT THE END\n['Shoulder discomfort (scapular stress fracture)', 'Strained lower back/ Rib stress fracture',\n 'Concussion/fractured jaw', 'Sports hernia stress fracture',\n 'Fractured foot (third metatarsal) / lisfranc sprai'\n]\n"

# %%
# Sickness/Illness terms v2

non_medical_mapping = {
    'TBD': 'Undisclosed',
    'Headaches': 'Headache',
    'Headaches/insomnia': 'Headache',
    'Migraine headaches': 'Headache',
    'Health and safety protocols': 'COVID-19_related',
    'Flu-like symptoms (mild)': 'Influenza',
    'Flu-like symptoms': 'Influenza',
    'Stomach flu': 'Influenza',
}

df["inj_norm_v4"] = (
    df["inj_norm_v4"]
        .astype("string")
        .str.strip()
        .replace(non_medical_mapping)
)

# %%
# TERM SEARCH KEY
filtered_entries = df['inj_norm_v4'][df['inj_norm_v4'].str.contains('boow', case=False, na=False)]
unique_infections = filtered_entries.unique() #
unique_infections_list = unique_infections.tolist()
print(unique_infections_list)
print(f"Number of unique infection-related injuries: {len(unique_infections)}")

# %%
# Full canon mapping

all_terms_mapped = {
    'TJ_terms': ['Tommy John surgery', 'Tommy John surgery revision',
                 'Tommy John internal brace surgery',
                 'Tommy John internal brace revision surgery',
                 'Tommy John surgery (non-throwing arm)'
                ],
    
    # potentially add laceration and dislocation
    'finger_terms': ['Sprained finger', 'Strained finger', 'Finger blister', 'Finger discomfort',
                      'Fractured finger', 'Finger surgery', 'Torn finger'
                    ],
    'hand_terms': ['Hand discomfort', 'Hand surgery', 'Fractured hand', 'Sprained hand',
                   'Hand blister','Hand contusion', 'Strained hand'
                   ],
    # potentially add 'Carpal Tunnel Syndrome', correct 'Wrist iscomfort' --> 'Wrist discomfort
    'wrist_terms': ['Wrist surgery', 'Sprained wrist', 'Wrist discomfort', 'Fractured wrist', 'Strained wrist'
                    ],
    'forearm_terms': ['Forearm discomfort', 'Strained forearm', 'Fractured forearm', 'Forearm surgery'
                      ],

    # map 'Elbow impingement' & 'Elbow contusion' --> 'Elbow discomfort'
    # map 'Hyperextended elbow' & 'Elbow laceration' &  'Elbow effusion' --> ???
    'elbow_terms': ['Elbow discomfort', 'Elbow stress reaction', 'Sprained elbow',
                    'Elbow surgery', 'Torn elbow', 'Strained elbow', 'Fractured elbow'
                    ],

    # map 'Arm fatigue' --> 'Arm discomfort'
    'arm_terms': ['Strained arm', 'Arm discomfort', 'Arm surgery'
                  ],
    'neck_terms': ['Neck discomfort', 'Neck spasms', 'Strained neck', 'Sprained neck', 'Neck surgery', 'Neck stress reaction'
                   ],
    # map 'Toe contusion' --> 'Toe discomfort, 'Turf toe' --> 'Torn Toe' OR LEAVE SEPARATE???
    'toe_terms': ['Fractured toe', 'Sprained toe', 'Toe blister', 'Toe discomfort',
                  'Toe surgery', 'Torn toe', 'Toe stress fracture', 'Toe stress reaction'
                  ],
    'ankle_terms': ['Sprained ankle', 'Ankle discomfort', 'Ankle surgery', 'Fractured ankle', 'Strained ankle'
                    ],
    'achilles_terms': ['Achilles tendon surgery', 'Achilles discomfort', 'Achilles tendon discomfort', 'Torn Achilles tendon', 'Strained Achilles tendon'
                       ],
    # map 'Foot contusion' --> 'Foot discomfort
    'foot_terms': ['Fractured foot', 'Sprained foot', 'Foot discomfort', 'Foot surgery',
                   'Strained foot', 'Foot blister', 'Foot stress reaction', 'Foot tear'
                   ],
    # 'Knee joint procedure' ???
    # 'Knee contusion' & 'Knee laceration' --> 'Knee discomfort
    # 'Knee hyperextension' & 'Tenex procedure (right knee)' & 'Kneecap subluxation' ???
    # 'Knee osteochondral defect' & 'Knee effusion' LONG TERM EFFECT??? DEBILITATING EFFECT???
    'knee_terms': ['Knee discomfort', 'Sprained knee', 'Strained knee', 'Knee surgery', 'Torn knee',
                    'Fractured knee', 'Toe surgery / Knee surgery'
                    ],
    # map 'Strained lower leg' --> to 'Strained calf' OR 'Strained leg'
    # map 'Leg contusion' & 'Leg contusion (tibia)' --> 'Leg discomfort'
    'leg_terms': ['Strained leg', 'Fractured leg', 'Leg discomfort', 'Leg stress reaction',
                  'Leg stress fracture', 'Torn leg', 'Leg surgery'
                  ],
    # finish mapping groin terms to hip
    # map 'Hip impingement' & 'Hip contusion' --> 'Hip discomfort' ???
    'hip_terms': ['Strained hip', 'Hip discomfort', 'Hip surgery', 'Torn hip'
                  ],
    # map 'Abdomen contusion' --> 'Abdominal discomfort'
    'abdominal_terms': ['Strained abdominal', 'Abdominal discomfort', 'Abdominal surgery'
                        ],
    # map 'Rib contusion' --> 'Rib discomfort' OR leave separate since bruised ribs is a big deal???
    'rib_terms': ['Fractured rib', 'Strained rib', 'Rib discomfort', 'Sprained rib',
                  'Rib stress reaction', 'Torn rib cartilage', 'Rib surgery'
                  ],
    # deal with 'disc herniation' variations
    # correct lower back to upper back mapping where necessary
    'lower_back_terms': ['Lower back spasms', 'Strained lower back', 'Lower back discomfort', 'Lower back surgery',
                         'Lower back stress reaction', 'Lower back stress fracture', 'Torn lower back', 'Sprained lower back'
                         ],
    
    # deal with 'Shoulder impingement', 'Shoulder separation', 'Shoulder dislocation' variants, 'Shoulder subluxation' variations
    # map 'Shoulder contusion' --> 'Shoulder discomfort'
    'shoulder_terms': ['Shoulder surgery', 'Shoulder discomfort', 'Sprained shoulder',
                       'Strained shoulder', 'Torn shoulder', 'Fractured shoulder', 'Shoulder stress fracture'
                       ],
    # there are some terms I missed beyond this list, but this sound encompass about 90% of the mapping I plan to use
    # need a 'non-injury_medical' category for non-sports related issues
    #   ex. cancers, non-sports injuries, miscellaneous terms, etc.
    # NOTE 'COVID-19_related', 'Influenza' MOVED TO 'illness_terms' for now
    'miscellaneous_terms': ['Undisclosed'] 
    # CALF RELATED INJURIES HAVE MOSTLY BEEN SKIPPED UP TO THIS POINT
    # CLASSIFY SHIN AND CALF TOGETHER???
    'calf_terms': ['Strained calf', 'Calf discomfort'
                   ],
    # maybe keep laceration because it is face???  else, map it to discomfort???
    'facial_terms': ['Facial surgery', 'Facial laceration', 'Facial fracture', 'Skull fracture'
                     ],
    
    #######################################
    # NEWLY CREATED TERMS BELOW THIS LINE #
    #######################################

    # INCOMPLETE, ADD VARIANTS AS NEEDED
    'illness_terms': ['COVID-19_related', 'Influenza', 'Infection'],

    # INCOMPLETE, ADD VARIANTS AS NEEDED
    'vascular_terms': ['Thoracic outlet syndrome', 'Thoracic outlet syndrome surgery'],

    # INCOMPLETE, ADD VARIANTS AS NEEDED
    'medical_non_injury_terms': ['Medical (Non-injury)', 'Surgery (Non-injury)']


}

# INCOMPLETE, ADD VARIANTS AS NEEDED
# 'illness_terms': ['COVID-19_related', 'Influenza', 'Infection'],

# INCOMPLETE, ADD VARIANTS AS NEEDED
# 'vascular_terms': ['Thoracic outlet syndrome', 'Thoracic outlet syndrome surgery'],

# INCOMPLETE, ADD VARIANTS AS NEEDED
# 'medical_non_injury_terms': ['Medical (Non-injury)', 'Surgery (Non-injury)']

# %%
terms_to_map = {
    'Surgery (colon cancer)': 'Medical (Non-injury)',    'Calf contusion': 'Calf discomfort',
    'Calf tenosynovitis': 'Calf discomfort',    'Biceps contusion': 'Arm discomfort',
    'Knee joint procedure': 'Knee surgery',    'Hip impingement': 'Hip discomfort',
    'Eye central serous chorioretinopathy': 'Medical (Non-injury)',    'Biceps nerve injury': 'Arm discomfort',
    'Benign bone tumor in spine': 'Medical (Non-injury)',    'Shin surgery (stress fracture)': 'Leg surgery',
    'Core surgery; Microdiscectomy': 'Lower back surgery',    'Elbow impingement': 'Elbow discomfort',
    'Wrist impingement': 'Wrist discomfort',    'Shin contusion': 'Leg discomfort',
    'Knee contusion': 'Knee discomfort',    'Thoracic outlet syndrome surgery': 'Thoracic outlet syndrome surgery',
    'Wrist contusion': 'Wrist discomfort',    'Shoulder impingement': 'Shoulder discomfort',
    'Quad contusion': 'Leg discomfort',    'Finger laceration': 'Finger discomfort',
    'Carpal tunnel syndrome surgery': 'Wrist surgery',    'Hyperextended elbow': 'Sprained elbow',
    'Toe contusion': 'Toe discomfort',    'Thumb contusion': 'Finger discomfort',
    'Hand contusion': 'Hand discomfort',    'Hamstring tendinitis': 'Leg discomfort',    
    'Elbow laceration': 'Elbow discomfort',    'Flexor tendon surgery': 'Flexor tendon surgery elbow surgery',
    'Abscess removal procedure (thigh)': 'Infection',    'Groin surgery': 'Hip surgery',
    'Carpal Tunnel Syndrome (right wrist)': 'Wrist surgery',    'Hamstring surgery': 'Leg surgery',
    'Partially torn elbow ligament': 'Torn elbow',    'Thumb weakness (left)': 'Finger discomfort',
    'Finger laceration (right index)': 'Finger discomfort',    'Ankle impingement': 'Ankle discomfort',
    'Elbow contusion': 'Elbow discomfort',    'Foot contusion': 'Foot discomfort',
    'Lat surgery': 'Shoulder surgery',    'Dislocated finger (left pinkie)': 'Sprained finger',
    'Thumb surgery': 'Finger surgery',    'Achilles tendon surgery (exploratory)': 'Achiilles tendon surgery',
    'Thumb abrasion (right)': 'Finger discomfort',    'Shoulder dislocation (left)': 'Sprained shoulder',
    'Heel contusion': 'Foot discomfort',    'Plantar fascitis': 'Foot discomfort',
    'Thumb laceration': 'Finger discomfort',    'Shoulder subluxation (left)': 'Sprained shoulder',
    'Finger dislocation (left index)': 'Finger dislocation',
    'Shoulder contusion': 'Shoulder discomfort',    'Calf contusion': 'Calf discomfort',
    'Knee effusion': 'Knee discomfort',    'Finger contusion': 'Finger discomfort',
    'Groin discomfort': 'Hip discomfort',    'Ulnar nerve transposition surgery': 'Elbow surgery',
    'Wrist contusion (left)': 'Wrist discomfort',    'Shoulder subluxation': 'Sprained shoulder',
    'Torn flexor tendon': 'Torn flexor tendon',    'Thumb contusion (left)': 'Finger discomfort',
    'Hand contusion (right)': 'Hand discomfort',    'Adductor surgery (hip/groin)': 'Hip surgery',
    'Core muscle surgery': 'Abdominal surgery',
    'Shoulder impingement syndrome': 'Shoulder discomfort',    'Triceps contusion': 'Arm discomfort',
    'Heel irritation': 'Foot discomfort',    'Shoulder dislocation (non-throwing)': 'Sprained shoulder (non-throwing)',
    'Mouth injury': 'Facial injury',    'Toe sesamoiditis': 'Toe discomfort',
    'Elbow effusion': 'Elbow discomfort',    'Cervical nerve impingement': 'Neck discomfort',
    'Thoracic outlet syndrome surgery (follow-up proced': 'Thoracic outlet syndrome surgery',
    'Thumb surgery (left)': 'Finger surgery',    'Finger laceration (right middle)': 'Finger discomfort',
    'Biceps surgery': 'Arm surgery',    'Face surgery (OZMC fracture)': 'Facial surgery',
    'Elbow valgus extension overload': 'Elbow discomfort',
    'Hand laceration': 'Hand discomfort',    'Knee laceration': 'Knee discomfort',
    'Foot metatarsalgia': 'Foot discomfort',    'Bone graft surgery (rib)': 'Rib surgery',
    'Abdomen contusion': 'Abdominal discomfort',    'Ulnar nerve inflammation': 'Elbow discomfort',
    'Shoulder discomfort (scapular stress fracture)': 'Shoulder stress fracture',    'Wrist iscomfort': 'Wrist discomfort',
    'Leg contusion': 'Leg discomfort',    'Thumb surgery (ligament repair)': 'Finger surgery',
    'Foot discomfort (partially torn plantar fascia)': 'Foot tear',    'Hip contusion': 'Hip discomfort',
    'Leg contusion (tibia)': 'Leg discomfort',    'Thoracic outlet depression surgery': 'Thoracic outlet syndrome surgery'
}

#####################################################
# CREATE NEW NORM LIST BEFORE APPLYING ANYTHING NEW #
#####################################################

df['inj_norm_v5'] = (
    df['inj_norm_v4']
)

df.head(1)

df["inj_norm_v5"] = (
    df["inj_norm_v5"]
        .astype("string")
        .str.strip()
        .replace(terms_to_map)
)

unique_injuries = df['inj_norm_v5'].unique()

print(f"Number of unique injury descriptions: {len(unique_injuries)}")

# Number of unique injury descriptions: 228
# Out:
# Number of unique injury descriptions: 228

# %%
# GIVEN MAPPING | NEEDS TO BE CLEANED UP

# Shoulder instability treated as sprain-type injury
shoulder_instability_map = {
    'Shoulder separation': 'Sprained shoulder',
    'Shoulder subluxation (non-throwing)': 'Sprained shoulder',
    'Shoulder dislocation': 'Sprained shoulder',
}

# PRP indicates tear-level pathology, not mere discomfort
shoulder_biologic_map = {
    'PRP injection in shoulder (torn rotator cuff)': 'Torn shoulder',
}

# Pectoral injuries are not shoulder or rib injuries
chest_injury_map = {
    'Chest contusion': 'Chest injury',
    'Strained pectoral': 'Chest injury',
}

chest_surgery_map = {
    'Pectoral surgery (ruptured tendon)': 'Chest surgery',
}

infection_map = {
    'Infection': 'Infection',
    'Viral enteritis': 'Infection',
    'Gastroenteritis': 'Infection',
    'Pneumonia': 'Infection',
    'Hand, foot, and mouth disease': 'Infection',
}

# Long-term systemic conditions
chronic_illness_map = {
    'Ulcerative colitis': 'Chronic illness',
    'Mononucleosis': 'Chronic illness',
}

medical_noninjury_map = {
    'Appendicitis': 'Medical (non-injury)',
    'Appendectomy': 'Medical (non-injury)',
    'Gastritis': 'Medical (non-injury)',
    'Esophageal constriction': 'Medical (non-injury)',
    'Kidney ailment': 'Medical (non-injury)',
    'Kidney stones': 'Medical (non-injury)',
    'Irregular heartbeat': 'Medical (non-injury)',
    'Medical procedure': 'Medical (non-injury)',
}

vascular_cardiac_map = {
    'Atrial fibrillation surgery': 'Vascular_cardiac_surgery',
    'Vascular surgery (upper arm aneurysm)': 'Vascular_cardiac_surgery',
    'Blood clot removal surgery (right elbow)': 'Vascular_cardiac_surgery',
}

# Consistent with earlier choice: lacerations → discomfort
hand_laceration_map = {
    'Thumb surgery (laceration)': 'Hand discomfort',
}

# Avoid over-granularity; classify conservatively
core_injury_map = {
    'Testicular contusion': 'Core discomfort',
}

# Cartilage/bone injury distinct from strain/sprain
knee_structural_map = {
    'Knee osteochondral defect': 'Knee structural injury',
}

# Partial tears treated as tear-level severity
knee_severity_map = {
    'Knee discomfort (partially torn patellar tendon)': 'Torn knee',
    'Sprained knee (torn MCL)': 'Torn knee',
}

# Instability-type injuries
knee_instability_map = {
    'Knee hyperextension': 'Sprained knee',
    'Kneecap subluxation': 'Sprained knee',
}

knee_procedure_map = {
    'Tenex procedure (right knee)': 'Knee surgery',
}

generic_symptom_map = {
    'Arm fatigue': 'Arm discomfort',
    'stress reaction': 'Stress reaction',
    'Blister': 'Skin injury',
    'Nerve-related issue': 'Nerve-related',
    'Tendon discomfort': 'Discomfort',
}

# Sports hernia is not a simple groin strain
sports_hernia_map = {
    'Sports hernia': 'Core injury',
    'Sports hernia stress fracture': 'Core injury',
}

sports_hernia_surgery_map = {
    'Sports hernia surgery': 'Core surgery',
}

facial_head_map = {
    'Fractured nose': 'Facial fracture',
    'Facial laceration': 'Facial injury',
    'Head contusion': 'Head injury',
}

neurological_map = {
    'Post-concussion syndrome': 'Concussion',
    'Lightheadedness/blurred vision': 'Neurological',
    'Vertigo': 'Neurological',
    'Anxiety': 'Mental health',
    'Mental health': 'Mental health',
}

# Cartilage/intercostal ≠ fracture
rib_cartilage_map = {
    'Rib costochondritis': 'Rib cartilage injury',
    'Intercostal irritation': 'Rib cartilage injury',
    'Torn rib cartilage': 'Rib cartilage injury',
    'Costochondral cartilage injury': 'Rib cartilage injury',
}

rib_contusion_map = {
    'Rib contusion': 'Rib discomfort',
}

# Turf toe is ligamentous and clinically distinct
toe_ligament_map = {
    'Turf toe': 'Toe ligament injury',
}

leg_map = {
    'Shin bone bruise': 'Leg discomfort',
    'Fractured shin': 'Leg fracture',
    'Shin splints': 'Leg stress reaction',
}

calf_map = {
    'Calf discomfort': 'Calf discomfort',
    'Calf tenosynovitis': 'Calf discomfort',
}

pelvis_map = {
    'Fractured pelvis': 'Pelvic fracture',
}

# Lat injuries biomechanically function as shoulder injuries
lat_map = {
    'Torn lat tendon': 'Torn shoulder',
    'Lat discomfort': 'Shoulder discomfort',
}

spinal_disc_map = {
    'Lower back disc herniation': 'Spinal disc injury',
    'Herniated disc in back': 'Spinal disc injury',
    'Spine disc injury': 'Spinal disc injury',
    'Lumbar degenerative disc disease': 'Spinal disc injury',
    'Mid-back disc herniation': 'Spinal disc injury',
}

# SI joint is pelvic, not shoulder
si_joint_map = {
    'Shoulder inflammation (SI joint)': 'Hip discomfort',
}

peripheral_map = {
    'Finger numbness': 'Nerve-related',
    'Forearm flexor tendinits': 'Forearm discomfort',
}

elbow_tendinitis_map = {
    'Elbow epicondylitis': 'Elbow tendinitis',
    'Elbow epicondylitis (right and left)': 'Elbow tendinitis',
    'Elbow lateral epicondylitis': 'Elbow tendinitis',
}

finger_dislocation_map = {
    'Finger dislocation (right pinkie)': 'Finger dislocation',
    'Finger dislocation (left pinky)': 'Finger dislocation',
}

# %%
unsure_list = {
    'Shoulder separation': 'Sprained shoulder',
    'Shoulder subluxation (non-throwing)': 'Sprained shoulder',
    'Shoulder dislocation': 'Sprained shoulder',
    'PRP injection in shoulder (torn rotator cuff)': 'Torn shoulder',
    'Chest contusion': 'Chest injury',
    'Strained pectoral': 'Chest injury',
    'Pectoral surgery (ruptured tendon)': 'Chest surgery',
    'Ulcerative colitis': 'Chronic illness',
    'Appendicitis': 'Medical (Non-injury)',
    'Gastritis': 'Medical (Non-injury)',
    'Viral enteritis': 'Infection',
    'Mononucleosis': 'Infection',
    'Hand, foot, and mouth disease': 'Infection',
    'Appendectomy': 'Medical (Non-injury)',
    'Gastroenteritis': 'Infection',
    'Pneumonia': 'Infection',
    'Esophageal constriction': 'Medical (Non-injury)',
    'Bruised lung': 'Medical (Non-injury)',
    'Kidney ailment': 'Medical (Non-injury)',
    'Thumb surgery (laceration)': 'Finger surgery',
    'Testicular contusion': 'Groin discomfort',
    'Knee osteochondral defect': 'Knee structural injury',
    'Arm fatigue': 'Arm discomfort',
    'stress reaction': 'Stress reaction (general)',
    'Blister': 'Bliser (general)',
    'Medical procedure': 'Medical (Non-injury)',
    'Nerve-related issue': 'Nerve-related (general)',
    'Atrial fibrillation surgery': 'Vascular cardiac surgery',
    'Vascular surgery (upper arm aneurysm)': 'Vascular cardiac surgery',
    'Blood clot removal surgery (right elbow)': 'Vascular cardiac surgery',
    'Fractured nose': 'Facial fracture',
    'Facial laceration' : 'Facial injury',
    'Rib costochondritis': 'Rib cartilage injury',
    'Intercostal irritation': 'Rib cartilage injury',
    'Torn rib cartilage': 'Torn rib cartilage',
    'Costochondral cartilage injury': 'Rib cartilage injury',
    'Rib contusion': 'Rib discomfort',
    'Lightheadedness/blurred vision': 'Neurological related',
    'Vertigo': 'Neurological related',
    'Anxiety': 'Mental health',
    'Post-concussion syndrome': 'Concussion',
    'Head contusion': 'Head injury',
    'Laser eye surgery': 'Medical (Non-injury)',
    'Dry eye syndrome': 'Medical (Non-injury)',
    'Irregular heartbeat': 'Vascular cardiac related',
    'Knee discomfort (partially torn patellar tendon)': 'Torn knee',
    'Knee hyperextension': 'Sprained knee',
    'Tenex procedure (right knee)': 'Knee surgery',
    'Kneecap subluxation': 'Sprained knee',
    'Sprained knee (torn MCL)': 'Torn knee',
    'Tendon discomfort': 'Tendon discomfort (general)',
    'Shin bone bruise': 'Leg discomfort',
    'Fractured shin': 'Fractured shin',
    'Calf tenosynovitis': 'Calf discomfort',
    'Shin splints': 'Shin stress reaction',
    "Non-Hodgkin's Lymphoma": 'Medical (Non-injury)',
    'Raynaud’s syndrome surgery': 'Medical (Non-injury)',
    'Kidney stones': 'Medical (Non-injury)',
    "Hodgkin's Lymphoma": 'Medical (Non-injury)',
    'Torn lat tendon': 'Torn shoulder',
    'Lat discomfort': 'Shoulder discomfort',
    'Lower back disc herniation': 'Spinal disc injury',
    'Herniated disc in back': 'Spinal disc injury',
    'Spine disc injury': 'Spinal disc injury',
    'Lumbar degenerative disc disease': 'Spinal disc injury',
    'Mid-back disc herniation': 'Spinal disc injury',
    'Finger numbness': 'Finger nerve-related',
    'Forearm flexor tendinits': 'Forearm discomfort',
    'Elbow epicondylitis': 'Elbow discomfort',
    'Elbow epicondylitis (right and left)': 'Elbow discomfort',
    'Elbow lateral epicondylitis': 'Elbow discomfort',
    'Finger dislocation (right pinkie)': 'Finger dislocation',
    'Finger dislocation (left pinky)': 'Finger dislocation'
}

df["inj_norm_v5"] = (
    df["inj_norm_v5"]
        .astype("string")
        .str.strip()
        .replace(unsure_list)
)

unique_injuries = df['inj_norm_v5'].unique()

print(f"Number of unique injury descriptions: {len(unique_injuries)}")

# Number of unique injury descriptions: 175
# Out:
# Number of unique injury descriptions: 175

# %%
# RAW VERSION, CLEANED VERSION ABOVE

unsure_list = [
    'Shoulder separation', 'Shoulder subluxation (non-throwing)', 'Shoulder dislocation', 'PRP injection in shoulder (torn rotator cuff)'
    'Chest contusion', 'Strained pectoral', 'Pectoral surgery (ruptured tendon)',# no chest category currently
    'Infection', # combine as illness/infection?  or leave separate in a non-injury bucket???
    'Ulcerative colitis', 'Appendicitis', 'Gastritis', 'Viral enteritis', 'Mononucleosis', 'Hand, foot, and mouth disease'
    'Appendectomy', 'Gastroenteritis', 'Pneumonia', # non-injury medical, unsure if long-term or short-term
    'Esophageal constriction', 'Bruised lung', 'Kidney ailment', # non-injury_medical?
    'Thumb surgery (laceration)', # stitches???
    'Testicular contusion', # unsure for this one...
    'Knee osteochondral defect', # unsure
    'Arm fatigue',  'stress reaction', 'Blister', 'Medical procedure', 'Nerve-related issue' # general?
    'Sports hernia', 'Sports hernia surgery', 'Sports hernia stress fracture', # general or assume groin???
    'Atrial fibrillation surgery', 'Vascular surgery (upper arm aneurysm)' # unsure
    'Blood clot removal surgery (right elbow)', # unsure
    'Fractured nose', 'Facial laceration' # confirm facial injury mapping
    'Rib costochondritis', 'Intercostal irritation', 'Torn rib cartilage', 'Costochondral cartilage injury' # specialty rib condition, add TORN RIB CARTILAGE
    'Rib contusion' # slightly different than standard bruise?  or just map as 'Rib discomfort' ???
    'Lightheadedness/blurred vision', 'Vertigo', 'Anxiety', 'Mental health', 'Post-concussion syndrome' # mental health/headache related???  Concussion/previous injury related???
        'Head contusion' # treat this differently than other contusions or just as 'Head discomfort' or 'Concussion' ???
    'Laser eye surgery', 'Dry eye syndrome' # non-injury_medical
    'Irregular heartbeat', # long term effect?
    'Turf toe', # CLASSIFY THIS ONE, BIG DEAL FOR NFL PLAYERS
    'Knee discomfort (partially torn patellar tendon)', 'Knee hyperextension',
        'Tenex procedure (right knee)', 'Kneecap subluxation', 'Sprained knee (torn MCL)'# discomfort, sprain, or tear?
    'Tendon discomfort', # too broad
    'Fractured pelvis', # I believe keep separate from hip
    'Shin bone bruise', 'Fractured shin', 'Calf discomfort', 'Calf tenosynovitis', 'Shin splints' # calf discomfort?
    "Non-Hodgkin's Lymphoma", 'Raynaud’s syndrome surgery', 'Kidney stones', "Hodgkin's Lymphoma" # non-injury medical
    'Torn lat tendon', 'Lat discomfort' # remap to back tear?
    'Lower back disc herniation', 'Herniated disc in back', 'Spine disc injury', 'Lumbar degenerative disc disease', 'Mid-back disc herniation'
    'Shoulder inflammation (SI joint)' # SI joint is hip.  Hip affecting shoulder?
    'Finger numbness' # neurological, nerve-related, or just standard discomfort?
    'Forearm flexor tendinits' # assume 'Forearm discomfort
    'Elbow epicondylitis', 'Elbow epicondylitis (right and left)', 'Elbow lateral epicondylitis'
    'Finger dislocation (right pinkie)', 'Finger dislocation (left pinky)' # add in a 'Finger dislocation' canon category
]

# %% [markdown]
# START OF v6 COL

# %%
# DOUBLE INJURY MAPPING

# mapped to a single injury without creating a new column (n is too small for this), or duplicating stint (skewing analysis)
# chose most severe of the given injuries
# CAN ATTMEPT TO CHANGE LATER FOR ANALYSIS TO SEE IF RESULTS VARY
double_injuries = {
    'Strained quad/knee contusion': 'Knee discomfort',
    'Concussion/fractured jaw': 'Facial fracture',
    'Strained oblique / Strained quad': 'Strained abdominal',
    'Elbow soreness / Strained hamstring': 'Elbow discomfort',
    'Flexor tendon surgery/Shoulder soreness': 'Flexor tendon surgery',
    'Elbow/back soreness': 'Elbow discomfort',
    'Elbow surgery (flexor tendon/bone spur)': 'Flexor tendon surgery',
    'Sprained wrist / bone bruise': 'Sprained wrist',
    'Strained lat/Torn shoulder capsule': 'Torn shoulder',
    'Elbow/Flexor tendon surgery': 'Flexor tendon surgery',
    'Strained lower back/ Rib stress fracture': 'Rib fracture',
    'Ankle/foot tendinitis': 'Ankle discomfort',
    'Fractured foot (third metatarsal) / lisfranc sprai': 'Sprained foot',
    'Toe surgery / Knee surgery': 'Knee surgery'
}

df["inj_norm_v6"] = (
    df["inj_norm_v5"]
)

df.head(1)
# Out:
#      player_name team pos inj_start  inj_desc         status   il_retro  \
# 0  Julio Teheran  LAA  SP  7/1/2020  COVID-19  Active roster  7/20/2020
#
#   eligible_return return_date latest_update  ...        source_file  \
# 0             NaN    8/5/2020     Activated  ...  2020_injuries.csv
#
#    days_to_return  flag_negative_days_to_return          inj_norm  \
# 0            35.0                         False  COVID-19_related
#
#         inj_norm_v1       inj_norm_v2       inj_norm_v3       inj_norm_v4  \
# 0  COVID-19_related  COVID-19_related  COVID-19_related  COVID-19_related
#
#         inj_norm_v5       inj_norm_v6
# 0  COVID-19_related  COVID-19_related
#
# [1 rows x 24 columns]

# %%
df["inj_norm_v6"] = (
    df["inj_norm_v6"]
        .astype("string")
        .str.strip()
        .replace(double_injuries)
)

unique_injuries = df['inj_norm_v6'].unique()

print(f"Number of unique injury descriptions: {len(unique_injuries)}")

# Number of unique injury descriptions: 163
# Out:
# Number of unique injury descriptions: 163

# %%
# list of all terms remaining
print(df['inj_norm_v6'].unique().tolist())
# Out:
# ['COVID-19_related', 'Undisclosed', 'Strained leg', 'Sprained ankle', 'Strained hip', 'Knee discomfort', 'Lower back spasms', 'Shoulder surgery', 'Tommy John surgery', 'Shoulder discomfort', 'Elbow discomfort', 'Fractured rib', 'Hip discomfort', 'Forearm discomfort', 'Strained abdominal', 'Sprained finger', 'Medical (Non-injury)', 'Wrist surgery', 'Elbow stress reaction', 'Strained calf', 'Sprained shoulder', 'Hand discomfort', 'Strained lower back', 'Arm discomfort', 'Knee surgery', 'Strained rib', 'Strained finger', 'Illness', 'Strained shoulder', 'Strained arm', 'Strained forearm', 'Fractured toe', 'Hand surgery', 'Sprained knee', 'Fractured hand', 'Sprained wrist', 'Sprained elbow', 'Lower back discomfort', 'Chest injury', 'Finger blister', 'Fractured forearm', 'Concussion', 'Elbow surgery', 'Hip surgery', 'Leg surgery', 'Lower back surgery', 'Fractured foot', 'Finger discomfort', 'Ankle discomfort', 'Sprained toe', 'Infection', 'Sprained hand', 'Torn elbow', 'Wrist discomfort', 
# ...

# %%
# injury_naming_convention_cleaning_v1_6 save

df.to_csv(r"C:\Users\brend\Desktop\SABR_research_proposal\injuries\processed\injuries_cleaned_v1_6.csv", index=False) # 1.6 contains 163 unique injuries
